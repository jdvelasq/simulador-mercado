# %%
import sys
from operator import itemgetter
import yaml
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#
# Load config from 'config.txt'
#
def load_config():
    with open("config.txt", "r") as f:
        configtxt = f.readlines()
    configtxt = "".join(configtxt)
    return yaml.load(configtxt, Loader=yaml.FullLoader)        

def save_config(data):
    with open("config.txt", "w") as f:
        yaml.dump(data, f)

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[129:256])
#df_Derivex.tail()
len(lista_Precio_Bolsa)
# Out:
# 127

# %% [markdown]
# ## Gráfico de barras Derivex y precio de bolsa

# %%
df_Derivex = pd.read_csv("data/Derivex_Pr_Diario.csv", sep = ",", decimal = ".")
#df_Derivex = df_Derivex.groupby(["Mes"], as_index = False).agg({"Precio": list})

flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)
df_Derivex.boxplot(column = "Precio", by = "Mes", figsize = (18, 8), grid = False, color="gray", flierprops=flierprops)
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.xlim(0,127)
#df_Derivex.index.name = None
#df_Derivex = df_Derivex.transpose()
#df_Derivex.tail()
# Out:
# (0, 127)

# %%
## CÓDIGO QUE VALE ORO
flierprops = dict(
    marker=",", linestyle="none", linewidth=0.1, markersize=12, markerfacecolor="k"
)
data.boxplot(
    column="diagnostico",
    by="fecha_diagnostico",
    grid=False,
    rot=90,
    figsize=(8, 4),
    color="gray",
    flierprops=flierprops,
)

# %% [markdown]
# ## Gráfico de barras precios simulados y precio en bolsa real

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[129:256])
t_base = 204
i_serie = 0
escenario_ONI = 10
escenario_Demanda = 1


filename_precio = "{}/PRECIO_Agente_{:04d}_ONI_{}_dem_{}.csv".format(
                        t_base, i_serie, escenario_ONI, escenario_Demanda
                    )
pd_precio = pd.read_csv(filename_precio)

# %%
CONFIG = load_config()
precios_10_1 = {}
precios_10_2 = {}
precios_10_3 = {}
precios_50_1 = {}
precios_50_2 = {}
precios_50_3 = {}
precios_90_1 = {}
precios_90_2 = {}
precios_90_3 = {}

for t_base in range(204, 241):
    
    precio_10_1 = []
    precio_10_2 = []
    precio_10_3 = []
    precio_50_1 = []
    precio_50_2 = []
    precio_50_3 = []
    precio_90_1 = []
    precio_90_2 = []
    precio_90_3 = []
    
    for escenario_ONI in CONFIG["ONI"]["ESCENARIOS"]:

        for escenario_Demanda in CONFIG["DEMANDA"]["ESCENARIOS"]:

            for i_serie in range(CONFIG["APORTES"]["NUMSIM"]):
                
                for horizonte in range(t_base, t_base + 24):

                    filename_precio = "{}/PRECIO_Agente_{:04d}_ONI_{}_dem_{}.csv".format(
                    t_base, i_serie, escenario_ONI, escenario_Demanda
                )
                    df_precio = pd.read_csv(filename_precio)

                    if escenario_ONI == 10 and escenario_Demanda == 1:

                        precio_10_1.append(df_precio.syntetic_Precio[horizonte])
                        
                    if escenario_ONI == 10 and escenario_Demanda == 2:

                        precio_10_2.append(df_precio.syntetic_Precio[horizonte])
                    
                    if escenario_ONI == 10 and escenario_Demanda == 3:

                        precio_10_3.append(df_precio.syntetic_Precio[horizonte])
                        
                    if escenario_ONI == 50 and escenario_Demanda == 1:

                        precio_50_1.append(df_precio.syntetic_Precio[horizonte])
                        
                    if escenario_ONI == 50 and escenario_Demanda == 2:

                        precio_50_2.append(df_precio.syntetic_Precio[horizonte])
                    
                    if escenario_ONI == 50 and escenario_Demanda == 3:

                        precio_50_3.append(df_precio.syntetic_Precio[horizonte])
                        
                    if escenario_ONI == 90 and escenario_Demanda == 1:

                        precio_90_1.append(df_precio.syntetic_Precio[horizonte])
                        
                    if escenario_ONI == 90 and escenario_Demanda == 2:

                        precio_90_2.append(df_precio.syntetic_Precio[horizonte])
                    
                    if escenario_ONI == 90 and escenario_Demanda == 3:

                        precio_90_3.append(df_precio.syntetic_Precio[horizonte])

                precios_10_1[t_base] = precio_10_1
                precios_10_2[t_base] = precio_10_2
                precios_10_3[t_base] = precio_10_3
                precios_50_1[t_base] = precio_50_1
                precios_50_2[t_base] = precio_50_2
                precios_50_3[t_base] = precio_50_3
                precios_90_1[t_base] = precio_90_1
                precios_90_2[t_base] = precio_90_2
                precios_90_3[t_base] = precio_90_3

                #df_precios_10_1 = pd.DataFrame(precios_10_1)

# %%
esc_10_1 =  pd.DataFrame(precios_10_1)
esc_10_2 =  pd.DataFrame(precios_10_2)
esc_10_3 =  pd.DataFrame(precios_10_3)
esc_50_1 =  pd.DataFrame(precios_50_1)
esc_50_2 =  pd.DataFrame(precios_50_2)
esc_50_3 =  pd.DataFrame(precios_50_3)
esc_90_1 =  pd.DataFrame(precios_90_1)
esc_90_2 =  pd.DataFrame(precios_90_2)
esc_90_3 =  pd.DataFrame(precios_90_3)

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_10_1.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_10_Dem_1")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.yscale("log")
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_10_2.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_10_Dem_2")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.yscale("log")
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_10_3.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_10_Dem_3")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_50_1.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_50_Dem_1")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_50_2.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_50_Dem_2")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_50_3.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_50_Dem_3")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_90_1.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_90_Dem_1")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_90_2.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_90_Dem_2")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.show()

# %%
df_Precio_Bolsa = pd.read_csv("data/data1.csv")
lista_Precio_Bolsa = list(Precio_Bolsa.Precio_Bolsa[204:])
flierprops = dict(
    marker=",", linestyle="none", linewidth = 0.2, markersize=12, markerfacecolor="k"
)

esc_90_3.boxplot(figsize = (14, 5), grid = False, color="gray", flierprops=flierprops)
plt.title("escenario_ONI_90_Dem_3")
plt.plot(lista_Precio_Bolsa, c = "k", linewidth = 2)
plt.yscale("log")
plt.show()
